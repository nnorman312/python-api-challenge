# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %%
# Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it's being processed (with the city number and city name).

url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
target_url = url + weather_api_key
target_url

cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0
    
# Loop through the list of cities and perform a request for data on each

for city in cities:
    weather_response = requests.get(target_url + "&q=" + city + "&units=Imperial")
    weather_json = weather_response.json()
    try:
        cityname.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        date.append(weather_json['list'][0]['dt'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"Processing record {count} | {city}")
    except:
        print("Record not found") 
        pass
# Out:
# Processing record 1 | upernavik
# Processing record 2 | bluff
# Processing record 3 | paka
# Processing record 4 | mataura
# Processing record 5 | barrow
# Processing record 6 | kadipaten
# Processing record 7 | carnarvon
# Record not found
# Processing record 8 | laguna
# Processing record 9 | rafaela
# Processing record 10 | aborlan
# Processing record 11 | ghanzi
# Processing record 12 | busselton
# Processing record 13 | yerbogachen
# Processing record 14 | hithadhoo
# Processing record 15 | castro
# Processing record 16 | esso
# Processing record 17 | lucea
# Processing record 18 | padang
# Processing record 19 | yatou
# Processing record 20 | shache
# Processing record 21 | portugalete
# Processing record 22 | san patricio
# Processing record 23 | batagay-alyta
# Record not found
# Processing record 24 | cape town
# Processing record 25 | san cristobal
# Processing record 26 | new norfolk
# Processing record 27 | clyde river
# Processing record 28 | qaanaaq
# Processing record 29 | lorengau
# Processing record 30 | punta arenas
# Processing record 31 | nanortalik
# Processing record 32 | tasiilaq
# Processing record 33 | souillac
# Processing record 34 | hermanus
# Record not found
# Processing record 35 | ushuaia
# Processing record 36 | atuona
# Processing record 37 | chuy
# Processing record 38 | vaini
# Processing record 39 | imeni stepana razina
# Processing record 40 | khatanga
# Processing record 41 | rikitea
# Record not found
# Record not found
# Processing record 42 | namibe
# Processing record 43 | constitucion
# Processing record 44 | vardo
# Processing record 45 | luderitz
# Processing record 46 | yellowknife
# Processing record 47 | salem
# Processing record 48 | chapais
# Processing record 49 | tagusao
# Processing record 50 | salym
# Processing record 51 | tingi
# Processing record 52 | kodiak
# Processing record 53 | hollister
# Processing record 54 | ostrovnoy
# Processing record 55 | kloulklubed
# Processing record 56 | tanete
# Processing record 57 | albany
# Record not found
# Processing record 58 | hasaki
# Processing record 59 | mikuni
# Processing record 60 | puerto escondido
# Processing record 61 | beisfjord
# Processing record 62 | salalah
# Processing record 63 | butaritari
# Processing record 64 | sakhon nakhon
# Processing record 65 | nizhniy tsasuchey
# Processing record 66 | sao filipe
# Processing record 67 | katsuura
# Processing record 68 | ulaangom
# Processing record 69 | shimoda
# Processing record 70 | kijang
# Processing record 71 | nikolskoye
# Record not found
# Processing record 72 | muroto
# Processing record 73 | east london
# Processing record 74 | havoysund
# Processing record 75 | saint george
# Processing record 76 | sao joao da ponte
# Processing record 77 | torbay
# Processing record 78 | cidreira
# Processing record 79 | naze
# Record not found
# Processing record 80 | ladario
# Processing record 81 | krasnoselkup
# Processing record 82 | mogadishu
# Processing record 83 | kapaa
# Processing record 84 | dwarka
# Processing record 85 | port alfred
# Processing record 86 | te anau
# Processing record 87 | anadyr
# Processing record 88 | hobart
# Record not found
# Processing record 89 | arraial do cabo
# Processing record 90 | asekeyevo
# Processing record 91 | cabo san lucas
# Processing record 92 | severnyy
# Processing record 93 | hilo
# Processing record 94 | horta
# Processing record 95 | manbij
# Processing record 96 | tongling
# Processing record 97 | airai
# Processing record 98 | palu
# Record not found
# Processing record 99 | tuktoyaktuk
# Processing record 100 | ocos
# Processing record 101 | natchitoches
# Processing record 102 | nome
# Processing record 103 | klaksvik
# Processing record 104 | ribeira grande
# Processing record 105 | ankazoabo
# Processing record 106 | saldanha
# Processing record 107 | gigmoto
# Processing record 108 | pisco
# Processing record 109 | bonthe
# Processing record 110 | gao
# Record not found
# Processing record 111 | soyo
# Processing record 112 | mahmudabad
# Processing record 113 | cap malheureux
# Processing record 114 | tessalit
# Processing record 115 | gimli
# Processing record 116 | las cruces
# Processing record 117 | faya
# Processing record 118 | bredasdorp
# Processing record 119 | kajaani
# Processing record 120 | vsetaty
# Processing record 121 | avarua
# Processing record 122 | sitka
# Processing record 123 | edd
# Processing record 124 | kismayo
# Processing record 125 | lufkin
# Processing record 126 | zambezi
# Processing record 127 | male
# Processing record 128 | murray bridge
# Processing record 129 | birakan
# Processing record 130 | apatity
# Processing record 131 | parry sound
# Processing record 132 | viedma
# Record not found
# Processing record 133 | teberda
# Processing record 134 | myitkyina
# Processing record 135 | kutum
# Processing record 136 | lake havasu city
# Processing record 137 | irituia
# Processing record 138 | zyryanskoye
# Record not found
# Processing record 139 | muli
# Processing record 140 | kenai
# Processing record 141 | alice springs
# Processing record 142 | pevek
# Processing record 143 | mount gambier
# Processing record 144 | ilulissat
# Processing record 145 | oranjemund
# Processing record 146 | gat
# Processing record 147 | jamestown
# Processing record 148 | svetlogorsk
# Processing record 149 | luanda
# Processing record 150 | fairbanks
# Processing record 151 | norman wells
# Processing record 152 | bengkulu
# Processing record 153 | plettenberg bay
# Processing record 154 | skibbereen
# Processing record 155 | awjilah
# Processing record 156 | guerrero negro
# Processing record 157 | lebu
# Processing record 158 | kruisfontein
# Processing record 159 | vao
# Processing record 160 | awbari
# Processing record 161 | tikapur
# Processing record 162 | la ronge
# Processing record 163 | mayo
# Processing record 164 | georgetown
# Processing record 165 | nouadhibou
# Processing record 166 | bethel
# Record not found
# Processing record 167 | kazanka
# Processing record 168 | zholymbet
# Processing record 169 | tres picos
# Processing record 170 | hualmay
# Processing record 171 | shelburne
# Processing record 172 | high level
# Processing record 173 | inirida
# Processing record 174 | kangaatsiaq
# Processing record 175 | severo-kurilsk
# Record not found
# Processing record 176 | kunashak
# Processing record 177 | saint-denis
# Processing record 178 | fare
# Processing record 179 | progreso
# Processing record 180 | karratha
# Processing record 181 | kvarkeno
# Processing record 182 | rawah
# Processing record 183 | port elizabeth
# Processing record 184 | coquimbo
# Processing record 185 | kano
# Processing record 186 | beloha
# Processing record 187 | hobyo
# Processing record 188 | seoul
# Processing record 189 | samarai
# Processing record 190 | kaeo
# Record not found
# Processing record 191 | shahrud
# Processing record 192 | caravelas
# Processing record 193 | santa maria
# Processing record 194 | ponta do sol
# Processing record 195 | shamkhal-termen
# Processing record 196 | redlands
# Processing record 197 | harer
# Processing record 198 | harper
# Processing record 199 | tazovskiy
# Processing record 200 | vermilion
# Processing record 201 | inhambane
# Processing record 202 | meadow lake
# Processing record 203 | quatre cocos
# Processing record 204 | wenzhou
# Processing record 205 | longyearbyen
# Processing record 206 | bud
# Processing record 207 | kawalu
# Processing record 208 | lubao
# Processing record 209 | lake charles
# Processing record 210 | nishihara
# Processing record 211 | lavrentiya
# Processing record 212 | araouane
# Processing record 213 | inyonga
# Processing record 214 | byron bay
# Processing record 215 | urdoma
# Processing record 216 | mandurah
# Processing record 217 | najran
# Processing record 218 | diamantino
# Processing record 219 | kasongo-lunda
# Processing record 220 | puerto ayora
# Processing record 221 | funadhoo
# Processing record 222 | polohy
# Processing record 223 | kabare
# Processing record 224 | solnechnyy
# Record not found
# Record not found
# Processing record 225 | la asuncion
# Processing record 226 | thompson
# Processing record 227 | killarney
# Processing record 228 | vincennes
# Processing record 229 | sydney
# Processing record 230 | gonzalez
# Processing record 231 | tura
# Processing record 232 | dunedin
# Processing record 233 | hecun
# Processing record 234 | havre-saint-pierre
# Processing record 235 | chokurdakh
# Processing record 236 | sioux lookout
# Processing record 237 | wanning
# Processing record 238 | shiyan
# Processing record 239 | big rapids
# Processing record 240 | tumaco
# Processing record 241 | axim
# Processing record 242 | namatanai
# Processing record 243 | barra
# Processing record 244 | inverbervie
# Processing record 245 | russell
# Processing record 246 | alekseyevsk
# Processing record 247 | mar del plata
# Processing record 248 | republic
# Record not found
# Processing record 249 | vostok
# Processing record 250 | fairmont
# Processing record 251 | fortuna
# Processing record 252 | richards bay
# Processing record 253 | ninghai
# Processing record 254 | grindavik
# Processing record 255 | broken hill
# Processing record 256 | saint-philippe
# Processing record 257 | rawson
# Processing record 258 | matara
# Processing record 259 | ust-nera
# Processing record 260 | atar
# Processing record 261 | lubango
# Processing record 262 | bereda
# Processing record 263 | balvi
# Processing record 264 | la lira
# Processing record 265 | road town
# Processing record 266 | onega
# Processing record 267 | tupik
# Processing record 268 | mahibadhoo
# Processing record 269 | ancud
# Processing record 270 | sakaiminato
# Processing record 271 | am timan
# Processing record 272 | cherskiy
# Processing record 273 | faanui
# Processing record 274 | canyon
# Processing record 275 | hamilton
# Processing record 276 | mahebourg
# Processing record 277 | poum
# Processing record 278 | koumac
# Processing record 279 | leningradskiy
# Processing record 280 | hambantota
# Record not found
# Record not found
# Processing record 281 | saint-ambroise
# Processing record 282 | ayr
# Processing record 283 | gebre guracha
# Processing record 284 | port lincoln
# Processing record 285 | santa fe
# Processing record 286 | malanje
# Processing record 287 | dakar
# Processing record 288 | vanavara
# Processing record 289 | bemidji
# Processing record 290 | terbuny
# Processing record 291 | sabha
# Processing record 292 | san quintin
# Processing record 293 | vila velha
# Processing record 294 | tuatapere
# Processing record 295 | rohru
# Processing record 296 | yantal
# Processing record 297 | laurel
# Processing record 298 | kavieng
# Processing record 299 | provideniya
# Processing record 300 | vila
# Processing record 301 | tual
# Processing record 302 | zyryanka
# Processing record 303 | nouakchott
# Record not found
# Processing record 304 | teahupoo
# Processing record 305 | ambulu
# Processing record 306 | kaitangata
# Processing record 307 | yulara
# Processing record 308 | okhotsk
# Processing record 309 | makakilo city
# Record not found
# Processing record 310 | kamenka
# Processing record 311 | santa cruz del sur
# Processing record 312 | rajgarh
# Processing record 313 | aklavik
# Processing record 314 | apen
# Processing record 315 | itoman
# Processing record 316 | riyadh
# Processing record 317 | usoke
# Processing record 318 | kirakira
# Record not found
# Processing record 319 | umea
# Processing record 320 | sorland
# Processing record 321 | alamogordo
# Processing record 322 | pingliang
# Processing record 323 | esperance
# Processing record 324 | requena
# Processing record 325 | pangnirtung
# Processing record 326 | touros
# Processing record 327 | ahipara
# Processing record 328 | baykit
# Processing record 329 | walvis bay
# Processing record 330 | geraldton
# Processing record 331 | mount isa
# Processing record 332 | sokoto
# Processing record 333 | yerofey pavlovich
# Processing record 334 | nikel
# Processing record 335 | gambela
# Processing record 336 | hakkari
# Record not found
# Processing record 337 | mountain home
# Processing record 338 | kingman
# Processing record 339 | pavlovsk
# Processing record 340 | nhulunbuy
# Processing record 341 | guayaramerin
# Record not found
# Processing record 342 | chicama
# Processing record 343 | henties bay
# Processing record 344 | pacific grove
# Processing record 345 | bambous virieux
# Processing record 346 | los llanos de aridane
# Processing record 347 | coria
# Processing record 348 | bharthana
# Processing record 349 | zlitan
# Record not found
# Processing record 350 | ahuimanu
# Processing record 351 | bubaque
# Processing record 352 | jiazi
# Processing record 353 | upata
# Processing record 354 | barcelos
# Processing record 355 | pionerskiy
# Processing record 356 | nankana sahib
# Processing record 357 | waipawa
# Processing record 358 | jiuquan
# Processing record 359 | tautira
# Processing record 360 | xichang
# Processing record 361 | sao jose da coroa grande
# Processing record 362 | umm kaddadah
# Processing record 363 | kazerun
# Processing record 364 | kyra
# Processing record 365 | berdigestyakh
# Processing record 366 | otradnoye
# Processing record 367 | baijiantan
# Processing record 368 | lohja
# Record not found
# Record not found
# Processing record 369 | tricase
# Record not found
# Processing record 370 | dingle
# Processing record 371 | auburn
# Processing record 372 | gravdal
# Processing record 373 | yenagoa
# Processing record 374 | la macarena
# Processing record 375 | santa cruz de la palma
# Processing record 376 | hami
# Processing record 377 | puerto colombia
# Processing record 378 | janauba
# Processing record 379 | nioro
# Processing record 380 | nuqui
# Record not found
# Processing record 381 | murupara
# Processing record 382 | quesnel
# Processing record 383 | quelimane
# Processing record 384 | beringovskiy
# Processing record 385 | gijon
# Processing record 386 | yima
# Processing record 387 | dongkan
# Processing record 388 | luba
# Processing record 389 | gloversville
# Processing record 390 | mayumba
# Processing record 391 | timbiqui
# Processing record 392 | tiksi
# Processing record 393 | tarnogskiy gorodok
# Processing record 394 | longonjo
# Processing record 395 | krasnozerskoye
# Processing record 396 | san javier
# Processing record 397 | chabahar
# Processing record 398 | rio grande
# Processing record 399 | rampur
# Processing record 400 | lompoc
# Processing record 401 | bilma
# Processing record 402 | nakhon phanom
# Processing record 403 | pemangkat
# Processing record 404 | traralgon
# Processing record 405 | uusikaupunki
# Processing record 406 | husavik
# Processing record 407 | oktyabrskiy
# Processing record 408 | marzuq
# Processing record 409 | bandar-e anzali
# Record not found
# Record not found
# Processing record 410 | urumqi
# Processing record 411 | tinskoy
# Record not found
# Processing record 412 | redmond
# Processing record 413 | vestmanna
# Processing record 414 | hofn
# Processing record 415 | arcachon
# Processing record 416 | la sarre
# Record not found
# Processing record 417 | tukrah
# Processing record 418 | nakano
# Record not found
# Processing record 419 | montepuez
# Processing record 420 | buraydah
# Processing record 421 | asau
# Processing record 422 | port hardy
# Record not found
# Record not found
# Processing record 423 | muncar
# Processing record 424 | taoudenni
# Processing record 425 | kankon
# Processing record 426 | lewisporte
# Processing record 427 | thaba-tseka
# Processing record 428 | birjand
# Processing record 429 | vestmannaeyjar
# Processing record 430 | marsh harbour
# Processing record 431 | georgiyevskoye
# Processing record 432 | launceston
# Processing record 433 | burgeo
# Processing record 434 | shubarkuduk
# Processing record 435 | victoria
# Processing record 436 | bay roberts
# Processing record 437 | forecariah
# Processing record 438 | erenhot
# Processing record 439 | sagaing
# Processing record 440 | manacor
# Processing record 441 | gunupur
# Processing record 442 | bako
# Processing record 443 | turukhansk
# Processing record 444 | san luis
# Processing record 445 | dhidhdhoo
# Processing record 446 | george town
# Processing record 447 | kez
# Processing record 448 | nemuro
# Processing record 449 | praia
# Processing record 450 | panama city
# Processing record 451 | saru dornei
# Processing record 452 | codrington
# Processing record 453 | palana
# Processing record 454 | baiyin
# Processing record 455 | paragould
# Processing record 456 | tatawin
# Processing record 457 | charyshskoye
# Processing record 458 | bullhead city
# Processing record 459 | wynyard
# Processing record 460 | comodoro rivadavia
# Processing record 461 | kibaya
# Processing record 462 | antofagasta
# Processing record 463 | carutapera
# Record not found
# Processing record 464 | tyrma
# Processing record 465 | trinidad
# Processing record 466 | maceio
# Processing record 467 | banes
# Processing record 468 | senanga
# Processing record 469 | chifeng
# Processing record 470 | narsaq
# Processing record 471 | qujing
# Processing record 472 | tank
# Processing record 473 | iqaluit
# Processing record 474 | tongchuan
# Processing record 475 | moose factory
# Record not found
# Processing record 476 | ballina
# Processing record 477 | marathon
# Processing record 478 | kefamenanu
# Processing record 479 | jalu
# Record not found
# Processing record 480 | kathu
# Processing record 481 | hobbs
# Processing record 482 | sola
# Processing record 483 | arawa
# Processing record 484 | portland
# Processing record 485 | houma
# Processing record 486 | khartoum
# Processing record 487 | varkaus
# Processing record 488 | manaure
# Processing record 489 | luena
# Processing record 490 | camocim
# Processing record 491 | poya
# Processing record 492 | alofi
# Processing record 493 | velizh
# Processing record 494 | fecamp
# Processing record 495 | rocha
# Processing record 496 | eirunepe
# Processing record 497 | omsukchan
# Processing record 498 | puerto del rosario
# Processing record 499 | maputo
# Processing record 500 | benjamin constant
# Record not found
# Processing record 501 | kavaratti
# Processing record 502 | manuk mangkaw
# Processing record 503 | taitung
# Processing record 504 | talnakh
# Processing record 505 | freetown
# Processing record 506 | jacareacanga
# Processing record 507 | coos bay
# Record not found
# Processing record 508 | springfield
# Record not found
# Processing record 509 | kiama
# Processing record 510 | socorro
# Processing record 511 | zhuhai
# Processing record 512 | hailey
# Processing record 513 | raga
# Processing record 514 | verkhnyaya inta
# Processing record 515 | marsabit
# Processing record 516 | lujiang
# Processing record 517 | grahamstown
# Processing record 518 | srandakan
# Record not found
# Processing record 519 | albury
# Processing record 520 | port keats
# Processing record 521 | petropavlovsk-kamchatskiy
# Processing record 522 | arlit
# Processing record 523 | chulym
# Processing record 524 | dikson
# Processing record 525 | tyret pervaya
# Processing record 526 | sao joao do paraiso
# Processing record 527 | sillod
# Processing record 528 | boa vista
# Processing record 529 | adrar
# Processing record 530 | fort nelson
# Processing record 531 | carballo
# Processing record 532 | buldana
# Processing record 533 | sur
# Processing record 534 | preobrazheniye
# Processing record 535 | straumen
# Processing record 536 | sena madureira
# Processing record 537 | colares
# Processing record 538 | ko samui
# Processing record 539 | saskylakh
# Processing record 540 | korla
# Record not found
# Processing record 541 | nautla
# Processing record 542 | belmonte
# Processing record 543 | grand gaube
# Processing record 544 | andradas
# Processing record 545 | tocopilla
# Processing record 546 | hearst
# Processing record 547 | saint-augustin
# Processing record 548 | tadine
# Processing record 549 | isangel
# Processing record 550 | zelenoborskiy
# Processing record 551 | falun
# Processing record 552 | bandiagara
# Processing record 553 | malaryta
# Processing record 554 | vanimo
# Processing record 555 | kitgum
# Processing record 556 | acapulco
# Processing record 557 | kalmunai
# Processing record 558 | braganca
# Processing record 559 | mareeba
# Processing record 560 | alyangula
# Processing record 561 | baisha
# Processing record 562 | jaguaribe
# Processing record 563 | pietersburg
# Processing record 564 | kemijarvi
# Processing record 565 | ambon
# Processing record 566 | baikunthpur
# Processing record 567 | namtsy
# Processing record 568 | zhangjiakou
# Processing record 569 | agirish
# Processing record 570 | constantine
# Processing record 571 | veselynove
# Processing record 572 | bathsheba
# Processing record 573 | marquette
# Processing record 574 | zaterechnyy
# Processing record 575 | el jicaro
# Processing record 576 | olafsvik
# Processing record 577 | tiznit
# Processing record 578 | moerai
# Processing record 579 | carauari
# Processing record 580 | palatka
# Processing record 581 | puerto leguizamo
# Processing record 582 | yar-sale
# Processing record 583 | yala
# Processing record 584 | broome
# Processing record 585 | tabuk
# Processing record 586 | san jose
# Processing record 587 | yambio
# Processing record 588 | hay river
# Processing record 589 | inuvik
# Record not found
# Processing record 590 | ucluelet
# Record not found
# Processing record 591 | port blair
# Processing record 592 | mildura
# Processing record 593 | bobo dioulasso
# Processing record 594 | avera
# Record not found
# Record not found
# Processing record 595 | filadelfia
# Processing record 596 | bogashevo
# Processing record 597 | ahwa
# Processing record 598 | tomatlan
# Processing record 599 | wichian buri
# Processing record 600 | sinnamary
# Processing record 601 | camacha

# %%
# Convert Raw Data to DataFrame

weather_df = {"City": cityname,"Latitude": lat, "Longitude":lng,
                "Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
                "Wind Speed":wind_speed,"Country":country, "Date":date}

weather_data = pd.DataFrame(weather_df)
weather_data.head(20)
# Out:
#            City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0     Upernavik   72.7868   -56.1549    -14.10        98          98
# 1         Bluff  -46.6000   168.3333     64.89        53         100
# 2          Paka    4.6374   103.4368     78.80        85          82
# 3       Mataura  -46.1927   168.8643     64.58        68         100
# 4        Barrow   71.2906  -156.7887      0.95        85          67
# 5     Kadipaten   -8.1357   113.2158     66.87        85         100
# 6     Carnarvon  -24.8667   113.6333     77.07        78          21
# 7        Laguna   38.4210  -121.4238     50.36        74         100
# 8       Rafaela  -31.2503   -61.4867     83.75        56         100
# 9       Aborlan    9.4352   118.5492     82.94        64          41
# 10       Ghanzi  -21.5667    21.7833     74.75        53          75
# 11    Busselton  -33.6500   115.3333     70.32        87          80
# 12  Yerbogachën   61.2767   108.0108     28.56        94         100
# 13    Hithadhoo   -0.6000    73.0833     82.83        64          64
# 14       Castro  -24.7911   -50.0119     64.40        67           0
# 15         Esso   55.9333   158.7000      6.46        82          16
# 16        Lucea   18.4510   -78.1736     80.02        80           0
# 17       Padang   -0.9492   100.3543     69.39        92          67
# 18        Yatou   37.1500   122.3833     42.73        59           0
# 19       Shache   38.4167    77.2406     41.32        33          21
#
#     Wind Speed Country        Date
# 0         3.60      GL  1584230400
# 1         2.84      NZ  1584230400
# 2         4.99      MY  1584230400
# 3         0.09      NZ  1584230400
# 4        24.07      US  1584230400
# 5         2.44      ID  1584230400
# 6         6.38      AU  1584230400
# 7        14.16      US  1584230400
# 8        19.71      AR  1584230400
# 9         2.77      PH  1584230400
# 10        4.16      BW  1584230400
# 11       13.04      AU  1584230400
# 12       11.07      RU  1584230400
# 13        3.47      MV  1584230400
# 14        2.06      BR  1584230400
# 15        4.88      RU  1584230400
# 16       13.27      JM  1584230400
# 17        4.65      ID  1584230400
# 18       13.96      CN  1584230400
# 19        5.17      CN  1584230400

# %%
# Export the data into a csv

weather_data.to_csv(r'output_data\weather_data.csv')

# %%
# Plotting the Data
# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# Save the plotted figures as .pngs.

# %%
# Temperature (F) vs. Latitude

scatlat = weather_data["Latitude"]
scattemp = weather_data["Max Temp"]

plt.scatter(scatlat,scattemp, color='pink')
plt.title(f'City Latitude vs. Max Temperature ({datetime.datetime.now().strftime("%D")})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('Temperature (F) vs Latitude')
plt.show()

print("This code plots the relationship between latitude and max temperature for the cities from the API call above. Based on the resulting scatterplot, as latitude increases, max temperature decreases.")
# Out:
# This code plots the relationship between latitude and max temperature for the cities from the API call above. Based on the resulting scatterplot, as latitude increases, max temperature decreases.

# %%
# Humidity (%) vs. Latitude

scathum = weather_data["Humidity"]

plt.scatter(scatlat,scathum, color='pink')
plt.title(f'City Latitude vs. Humidity ({datetime.datetime.now().strftime("%D")})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('Humidity (%) vs Latitude')
plt.show()

print("This code plots the relationship between latitude and humidity. Based on the resulting scatterplot, most cities humidity is over 40%. The lowest humidity percentage is found in cities with latitudes around ~20.")
# Out:
# This code plots the relationship between latitude and humidity. Based on the resulting scatterplot, most cities humidity is over 40%. The lowest humidity percentage is found in cities with latitudes around ~20.

# %%
# Cloudiness (%) vs. Latitude

scatcloud = weather_data["Cloudiness"]

plt.scatter(scatlat,scatcloud, color='pink')
plt.title(f'City Latitude vs. Cloudiness ({datetime.datetime.now().strftime("%D")})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('Cloudiness (%) vs Latitude')
plt.show()

print("This code plots the relationship between latitude and cloudiness. Based on the resulting scatterplot, there are lots of cities with 100% and 0% cloudiness, regardless of latitude. It appears that 0 latitude has a higher percentage of cloudiness (over 40%).")
# Out:
# This code plots the relationship between latitude and cloudiness. Based on the resulting scatterplot, there are lots of cities with 100% and 0% cloudiness, regardless of latitude. It appears that 0 latitude has a higher percentage of cloudiness (over 40%).

# %%
# Wind Speed (mph) vs. Latitude

scatwindsp = weather_data["Wind Speed"]

plt.scatter(scatlat,scatwindsp, color='pink')
plt.title(f'City Latitude vs. Wind Speed ({datetime.datetime.now().strftime("%D")})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('Wind Speed (mph) vs Latitude')
plt.show()

print("This code plots the relationship between latitude and wind speed. Based on the resulting scatterplot, most cities have wind speed under 30 mph. A city with a latitude of -20 has the highest wind speed (50 mph) and the next highest wind speed (~40 mph) is in a city with ~65 latitude.")
# Out:
# This code plots the relationship between latitude and wind speed. Based on the resulting scatterplot, most cities have wind speed under 30 mph. A city with a latitude of -20 has the highest wind speed (50 mph) and the next highest wind speed (~40 mph) is in a city with ~65 latitude.

# %%
# Set up the linear regression formulas and scatterplots

def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    
    plt.scatter(x_values,y_values, color='pink')
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Set up the northern and southern hemisphere dataframes

northlat_df = weather_data.loc[weather_data["Latitude"] >= 0,:]
southlat_df = weather_data.loc[weather_data["Latitude"] < 0,:]

northlat_df.head()
# Out:
#         City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Upernavik   72.7868   -56.1549    -14.10        98          98        3.60
# 2       Paka    4.6374   103.4368     78.80        85          82        4.99
# 4     Barrow   71.2906  -156.7887      0.95        85          67       24.07
# 7     Laguna   38.4210  -121.4238     50.36        74         100       14.16
# 9    Aborlan    9.4352   118.5492     82.94        64          41        2.77
#
#   Country        Date
# 0      GL  1584230400
# 2      MY  1584230400
# 4      US  1584230400
# 7      US  1584230400
# 9      PH  1584230400

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression

x_values = northlat_df["Latitude"]
y_values = northlat_df["Max Temp"]
plt.title(f'Northern Hemisphere - Max Temp vs. Latitude ({datetime.datetime.now().strftime("%D")})')
plot_linear_regression(x_values,y_values,'Max Temp', (6,30))

plt.savefig('NH Max Temp vs Latitude')

print("The high r value indicates a strong negative correlation between latitude and max temperature. In the northern hemisphere, as latitude increases, max temperature decreases.")
# Out:
# The r-squared is: -0.8995183503038453
# The high r value indicates a strong negative correlation between latitude and max temperature. In the northern hemisphere, as latitude increases, max temperature decreases.

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression

x_values = southlat_df["Latitude"]
y_values = southlat_df["Max Temp"]
plt.title(f'Southern Hemisphere - Max Temp vs. Latitude ({datetime.datetime.now().strftime("%D")})')
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig('SH Max Temp vs Latitude')

print("The r value indicates a medium positive correlation between latitude and max temperature. In the southern hemisphere, as latitude increases, max temperature increases.")
# Out:
# The r-squared is: 0.5647948420879061
# The r value indicates a medium positive correlation between latitude and max temperature. In the southern hemisphere, as latitude increases, max temperature increases.

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

x_values = northlat_df["Latitude"]
y_values = northlat_df["Humidity"]
plt.title(f'Northern Hemisphere - Humidity vs. Latitude ({datetime.datetime.now().strftime("%D")})')
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('NH Humidity vs Latitude')

print("The r value indicates a low positive correlation between latitude and humidity. In the northern hemisphere, as latitude increases, humidity increases.")
# Out:
# The r-squared is: 0.2992933809673657
# The r value indicates a low positive correlation between latitude and humidity. In the northern hemisphere, as latitude increases, humidity increases.

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

x_values = southlat_df["Latitude"]
y_values = southlat_df["Humidity"]
plt.title(f'Southern Hemisphere - Humidity vs. Latitude ({datetime.datetime.now().strftime("%D")})')
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('SH Humidity vs Latitude')

print("The r value indicates a low positive correlation between latitude and humidity. In the southern hemisphere, as latitude increases, humidity increases.")
# Out:
# The r-squared is: 0.3722322917005613
# The r value indicates a low positive correlation between latitude and humidity. In the southern hemisphere, as latitude increases, humidity increases.

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

x_values = northlat_df["Latitude"]
y_values = northlat_df["Cloudiness"]
plt.title(f'Northern Hemisphere - Cloudiness vs. Latitude ({datetime.datetime.now().strftime("%D")})')
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('NH Cloudiness (%) vs Latitude')

print("The r value indicates a low positive correlation between latitude and cloudiness. In the northern hemisphere, as latitude increases, cloudiness increases.")
# Out:
# The r-squared is: 0.19795636712658446
# The r value indicates a low positive correlation between latitude and cloudiness. In the northern hemisphere, as latitude increases, cloudiness increases.

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

x_values = southlat_df["Latitude"]
y_values = southlat_df["Cloudiness"]
plt.title(f'Southern Hemisphere - Cloudiness vs. Latitude ({datetime.datetime.now().strftime("%D")})')
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('SH Cloudiness (%) vs Latitude')

print("The r value indicates a low positive correlation between latitude and cloudiness. In the southern hemisphere, as latitude increases, cloudiness increases.")
# Out:
# The r-squared is: 0.35570270708870627
# The r value indicates a low positive correlation between latitude and cloudiness. In the southern hemisphere, as latitude increases, cloudiness increases.

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

x_values = northlat_df["Latitude"]
y_values = northlat_df["Wind Speed"]
plt.title(f'Northern Hemisphere - Wind Speed vs. Latitude ({datetime.datetime.now().strftime("%D")})')
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('NH Wind Speed (mph) vs Latitude')

print("The r value indicates a low positive correlation between latitude and wind speed. In the northern hemisphere, as latitude increases, wind speed increases.")
# Out:
# The r-squared is: 0.15401446237841065
# The r value indicates a low positive correlation between latitude and wind speed. In the northern hemisphere, as latitude increases, wind speed increases.

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

x_values = southlat_df["Latitude"]
y_values = southlat_df["Wind Speed"]
plt.title(f'Southern Hemisphere - Wind Speed vs. Latitude ({datetime.datetime.now().strftime("%D")})')
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('SH Wind Speed (mph) vs Latitude')

print("The r value indicates a low negative correlation between latitude and wind speed. In the southern hemisphere, as latitude increases, wind speed decreases.")
# Out:
# The r-squared is: -0.24080149826971423
# The r value indicates a low negative correlation between latitude and wind speed. In the southern hemisphere, as latitude increases, wind speed decreases.
